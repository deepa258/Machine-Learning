# %% [markdown]
# In this project, I will be fitting regression models to data from the Boston Housing Study. All the explanatory variables (except neighborhood) and all 506 census tract observations from the Boston Housing Study will be used for this analysis. I will be using the median value of homes in thousands of 1970 dollars. The two regression modeling methods used here will be:
#
# 1. Linear regression
# 2. Ridge regression
#
# These methods are evaluated within a cross-validation design, using root-mean-squared error (RMSE) as an index of prediction error.
#
# After analyzing the results from the two methods, I would suggest using the Ridge regression as opposed to the Linear regression for assessing the Market Value of residential real estate. This is because the RMSE and R-Squared values obtained in the cross-validation design show that Ridge Regression is performing better and has a better fit to the model data than the Linear Regression.

# %% [markdown]
# ### Data Preparation

# %%
# Setting the seed to obtain reproducible results

RANDOM_SEED = 1

# Fitting the intercept term in the models

SET_FIT_INTERCEPT = True

# Importing base packages

import numpy as np
import pandas as pd

# Importing Modeling routines from Scikit Learn packages

import sklearn.linear_model 
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score  
from math import sqrt

# %%
# Reading data for the Boston Housing Study

boston_input = pd.read_csv('boston.csv')

# Displaying attribute list in Boston DataFrame
# This is necessary to check the attribute types and 
# If the fields can contain Null data or not

print('\nGeneral description of the boston_input DataFrame:')
print(boston_input.info())

# Dropping neighborhood attribute from the data being considered

boston = boston_input.drop('neighborhood', 1)

# Displaying descriptive stats of Boston DataFrame

print('\nDescriptive statistics of the boston DataFrame:')
print(boston.describe())
# Out:
# General description of the boston_input DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# neighborhood    506 non-null object
# crim            506 non-null float64
# zn              506 non-null float64
# indus           506 non-null float64
# chas            506 non-null int64
# nox             506 non-null float64
# rooms           506 non-null float64
# age             506 non-null float64
# dis             506 non-null float64
# rad             506 non-null int64
# tax             506 non-null int64
# ptratio         506 non-null float64
# lstat           506 non-null float64
# mv              506 non-null float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 55.4+ KB
# None
#
# Descriptive statistics of the boston DataFrame:
#              crim          zn       indus        chas         nox       rooms  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# std     28.148861    2.105710    8.707259  168.537116    2.164946    7.141062
# min      2.900000    1.129600    1.000000  187.000000   12.600000    1.730000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000    6.950000
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000   11.360000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000   16.955000
# max    100.000000   12.126500   24.000000  711.000000   22.000000   37.970000
#
#                mv
# count  506.000000
# mean    22.528854
# std      9.182176
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %%
# Setting up the preliminary data model 
# the first column is the median housing value response
# the remaining columns are the explanatory variables

prelim_model_data = np.array([boston.mv,\
    boston.crim,\
    boston.zn,\
    boston.indus,\
    boston.chas,\
    boston.nox,\
    boston.rooms,\
    boston.age,\
    boston.dis,\
    boston.rad,\
    boston.tax,\
    boston.ptratio,\
    boston.lstat]).T

# Looking at the data before standardization

print('\nData dimensions:', prelim_model_data.shape)
# Out:
# Data dimensions: (506, 13)

# %%
# Importing StandardScaler to standardize the model data

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# the model data will be standardized form of preliminary model data

model_data = scaler.fit_transform(prelim_model_data)

# Looking at the data after standardization

print('\nDimensions for model_data:', model_data.shape)
# Out:
# Dimensions for model_data: (506, 13)

# %% [markdown]
# ### Regression of Data using Linear Regression and Ridge Regression in the K-Fold design and Cross-Validation of the Models using RMSE

# %%
# Setting names list containing names of the regression models
# Setting the regressors list specifying the regression models
# In Ridge regression, we are keeping alpha = 1

names = ['Linear_Regression', 'Ridge_Regression alpha=0.1',
         'Ridge_Regression alpha=1',
         'Ridge_Regression alpha=2', 'Ridge_Regression alpha=5' , 
         'Ridge_Regression alpha=500']

regressors = [LinearRegression(fit_intercept = SET_FIT_INTERCEPT, 
              normalize = False), 
              Ridge(alpha = 0.1, solver = 'cholesky', 
                    fit_intercept = SET_FIT_INTERCEPT, 
                    normalize = False, 
                    random_state = RANDOM_SEED), 
              Ridge(alpha = 1, solver = 'cholesky', 
                    fit_intercept = SET_FIT_INTERCEPT, 
                    normalize = False, 
                    random_state = RANDOM_SEED),
              Ridge(alpha = 2, solver = 'cholesky', 
                    fit_intercept = SET_FIT_INTERCEPT, 
                    normalize = False, 
                    random_state = RANDOM_SEED), 
              Ridge(alpha = 5, solver = 'cholesky', 
                    fit_intercept = SET_FIT_INTERCEPT, 
                    normalize = False, 
                    random_state = RANDOM_SEED), 
              Ridge(alpha = 500, solver = 'cholesky', 
                    fit_intercept = SET_FIT_INTERCEPT, 
                    normalize = False, 
                    random_state = RANDOM_SEED)]

# %%
# Specifying the folds for validation - 10-fold cross-validation

from sklearn.model_selection import KFold

# Specifying the folds for validation - 10-fold cross-validation

N_FOLDS = 10

# Setting up numpy array for storing results

cv_results = np.zeros((N_FOLDS, len(names)))

# Setting the KFold object using number of folds and 
# random seed set previously

kf = KFold(n_splits = N_FOLDS, shuffle=False, random_state = RANDOM_SEED)

# Checking the splitting process by looking at fold observation counts
# Initializing the fold count and looping through the splits of model data
# The variable index_for_fold will be used as the results array index

index_for_fold = 0 

# This loop will run 10 times, once for each fold

for train_index, test_index in kf.split(model_data):
    print('\nFold index:', index_for_fold,
          '------------------------------------------')
        
#   1:model_data.shape[1] slices for explanatory variables
#   and 0 is the index for the response variable 
#   Storing the split index in a variable to avoid recalculation

    model_data_exp = model_data.shape[1]

# Generating Train and Test datasets for the current fold
   
    X_train = model_data[train_index, 1:model_data_exp]
    X_test = model_data[test_index, 1:model_data_exp]
    y_train = model_data[train_index, 0]
    y_test = model_data[test_index, 0]   

# Initializing the method count and looping through the methods 
# (Linear Regression and Ridge Regression)
# This loop will run twice, once for each method, per fold
# The variable index_for_method will be used as results array index
    
    index_for_method = 0
    for name, reg_model in zip(names, regressors):
        print('\nRegression model evaluation for:', name)
        reg_model.fit(X_train, y_train)
        
        # evaluate on the test set for this fold
        y_test_predict = reg_model.predict(X_test)
        print('Coefficient of determination (R-squared):',
              r2_score(y_test, y_test_predict))
        fold_method_result = sqrt(mean_squared_error(y_test, y_test_predict))
        
        print('Root mean-squared error:', fold_method_result)
        cv_results[index_for_fold, index_for_method] = fold_method_result
        index_for_method += 1
  
    index_for_fold += 1

cv_results_df = pd.DataFrame(cv_results)
cv_results_df.columns = names

print('\n----------------------------------------------')
print('Average results from ', N_FOLDS, '-fold cross-validation\n',
      'in standardized units (mean 0, standard deviation 1)\n',
      '\nMethod               Root mean-squared error', sep = '')     
print(cv_results_df.mean())
# Out:
# Fold index: 0 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): 0.765075234937901
# Root mean-squared error: 0.3080338355432655
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): 0.7652758652644297
# Root mean-squared error: 0.3079022739996639
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): 0.7670378077121718
# Root mean-squared error: 0.30674447231421376
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): 0.7689061806957396
# Root mean-squared error: 0.3055119400905162
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): 0.7739891277941462
# Root mean-squared error: 0.30213336567902116
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.5543979021412023
# Root mean-squared error: 0.42423611437645087
#
# Fold index: 1 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): 0.4606757462846298
# Root mean-squared error: 0.41488851922454006
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): 0.4611991870556732
# Root mean-squared error: 0.4146871354707668
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): 0.46579221712274754
# Root mean-squared error: 0.41291584361267397
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): 0.4706622436050155
# Root mean-squared error: 0.41102939117630555
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): 0.48399918691730637
# Root mean-squared error: 0.4058183068745278
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.5353530495329573
# Root mean-squared error: 0.38509509518300816
#
# Fold index: 2 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): -1.3111751376507303
# Root mean-squared error: 0.43893840025417113
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): -1.308066739463265
# Root mean-squared error: 0.4386431274354482
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): -1.2803147541226507
# Root mean-squared error: 0.4359980497370265
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): -1.2499722639424773
# Root mean-squared error: 0.43308758094634814
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): -1.1623326217397594
# Root mean-squared error: 0.42456911465020714
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.019632857563705586
# Root mean-squared error: 0.2858785177139413
#
# Fold index: 3 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): 0.6328856607774366
# Root mean-squared error: 0.6522437994589771
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): 0.632778976093328
# Root mean-squared error: 0.6523385647155194
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): 0.6318124406179924
# Root mean-squared error: 0.6531964867707822
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): 0.6307267010220593
# Root mean-squared error: 0.6541588756460898
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): 0.6274152030547739
# Root mean-squared error: 0.657085449185097
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.24066871457532457
# Root mean-squared error: 0.9380477196008359
#
# Fold index: 4 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): 0.534228683154006
# Root mean-squared error: 0.6217833818375663
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): 0.5344400553963562
# Root mean-squared error: 0.6216422796945709
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): 0.5363005637661604
# Root mean-squared error: 0.6203989076135009
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): 0.5382829560214438
# Root mean-squared error: 0.6190713329069513
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): 0.5437422539600063
# Root mean-squared error: 0.6154005298742452
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.42502875366352433
# Root mean-squared error: 0.6908373408490422
#
# Fold index: 5 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): 0.7248910073380554
# Root mean-squared error: 0.4960115288286528
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): 0.7249241657418446
# Root mean-squared error: 0.4959816362286177
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): 0.7251740530340212
# Root mean-squared error: 0.49575630260601494
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): 0.7253567058400717
# Root mean-squared error: 0.495591532264692
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): 0.7254012178348863
# Root mean-squared error: 0.49555136987574305
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.3099421825190791
# Root mean-squared error: 0.7855649855963003
#
# Fold index: 6 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): 0.3782678938987153
# Root mean-squared error: 0.343828185197933
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): 0.3791565278902058
# Root mean-squared error: 0.3435823826546028
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): 0.3867221835948036
# Root mean-squared error: 0.34148250243968453
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): 0.39429438153869967
# Root mean-squared error: 0.33936779652065446
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): 0.41272156574000185
# Root mean-squared error: 0.33416568760053333
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.0761520347651169
# Root mean-squared error: 0.41912163617903925
#
# Fold index: 7 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): -0.014566207830289502
# Root mean-squared error: 1.3408272247731299
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): -0.014391540279010906
# Root mean-squared error: 1.3407118015079873
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): -0.012805869231099276
# Root mean-squared error: 1.3396635083924249
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): -0.011019736031855576
# Root mean-squared error: 1.3384817057216916
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): -0.005566539287655159
# Root mean-squared error: 1.3348671012190818
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.20607998021004692
# Root mean-squared error: 1.1860991634878044
#
# Fold index: 8 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): -1.0410008417604217
# Root mean-squared error: 0.6697047890403506
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): -1.0407083462484632
# Root mean-squared error: 0.6696567996765759
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): -1.038158832930784
# Root mean-squared error: 0.6692383585726626
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): -1.0354871089595274
# Root mean-squared error: 0.6687995786115847
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): -1.0283063155084418
# Root mean-squared error: 0.6676188404293073
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): -0.8366992637679256
# Root mean-squared error: 0.6353029012110472
#
# Fold index: 9 ------------------------------------------
#
# Regression model evaluation for: Linear_Regression
# Coefficient of determination (R-squared): 0.4779573572609961
# Root mean-squared error: 0.33313776358736685
#
# Regression model evaluation for: Ridge_Regression alpha=0.1
# Coefficient of determination (R-squared): 0.47909110498345275
# Root mean-squared error: 0.3327758204840675
#
# Regression model evaluation for: Ridge_Regression alpha=1
# Coefficient of determination (R-squared): 0.4886205199966541
# Root mean-squared error: 0.3297178997223902
#
# Regression model evaluation for: Ridge_Regression alpha=2
# Coefficient of determination (R-squared): 0.49793994266027153
# Root mean-squared error: 0.3266996820605495
#
# Regression model evaluation for: Ridge_Regression alpha=5
# Coefficient of determination (R-squared): 0.5197525974133069
# Root mean-squared error: 0.31952392948288705
#
# Regression model evaluation for: Ridge_Regression alpha=500
# Coefficient of determination (R-squared): 0.5696459375013894
# Root mean-squared error: 0.3024710609475875
#
# ----------------------------------------------
# Average results from 10-fold cross-validation
# in standardized units (mean 0, standard deviation 1)
#
# Method               Root mean-squared error
# Linear_Regression             0.561940
# Ridge_Regression alpha=0.1    0.561792
# Ridge_Regression alpha=1      0.560511
# Ridge_Regression alpha=2      0.559180
# Ridge_Regression alpha=5      0.555673
# Ridge_Regression alpha=500    0.605265
# dtype: float64

# %% [markdown]
# The mean RMSE value of Ridge Regression is slightly better (lower) than Linear Regression and the R-Squared values of Ridge Regression are slightly better (higher) than the Linear Regression. This shows that Ridge Regression has better performance on the data and can do a better job at predicting the value of the response variable (the median value of homes) using all the explanatory variables. In Ridge Regression, as the Alpha value increases, the R-Squared increases and RMSE value decreases which is an indication that it reduces overfitting on the data but as is seen in the case of a very high alpha value (500), the RMSE has increased which shows the underfitting of data.
